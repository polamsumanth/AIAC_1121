# %% [markdown]
# <a href="https://colab.research.google.com/github/polamsumanth/AIAC_1121/blob/main/AIAC_1121_LAB_13_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK 01**

# %% [markdown]
# **ORIGINAL CODE**

# %%
length = 8
width = 4
print("Area:", length * width)
print("Perimeter:", 2 * (length + width))

length = 12
width = 6
print("Area:", length * width)
print("Perimeter:", 2 * (length + width))
# Out:
# Area: 32
# Perimeter: 24
# Area: 72
# Perimeter: 36

# %% [markdown]
# **REFACTORED CODE**

# %%
def calculate_rectangle(length, width):
    area = length * width
    perimeter = 2 * (length + width)

    print("Area:", area)
    print("Perimeter:", perimeter)

calculate_rectangle(8, 4)
calculate_rectangle(12, 6)
# Out:
# Area: 32
# Perimeter: 24
# Area: 72
# Perimeter: 36

# %% [markdown]
# **TASK 02**

# %% [markdown]
# **ORIGINAL CODE**

# %%
amount = 1000
discount = amount * 0.10
final_amount = amount - discount
print("Final Amount:", final_amount)

amount = 2000
discount = amount * 0.10
final_amount = amount - discount
print("Final Amount:", final_amount)
# Out:
# Final Amount: 900.0
# Final Amount: 1800.0

# %% [markdown]
# **REFACTORED CODE**

# %%
def calculate_final_amount(amount):
    discount = amount * 0.10
    final_amount = amount - discount
    print("Final Amount:", final_amount)

calculate_final_amount(1000)
calculate_final_amount(2000)
# Out:
# Final Amount: 900.0
# Final Amount: 1800.0

# %% [markdown]
# **TASK 03**

# %% [markdown]
# **ORIGINAL CODE**

# %%
students = ["Anil", "Bhavya", "Charan", "Divya"]
check_list = ["Charan", "Esha", "Bhavya"]
for name in check_list:
  exists = False
  for student in students:
    if name == student:
      exists = True
if exists:
  print(name, "found")
else:
  print(name, "not found")
# Out:
# Bhavya found

# %% [markdown]
# **REFACTORED CODE**

# %%
students = ["Anil", "Bhavya", "Charan", "Divya"]
check_list = ["Charan", "Esha", "Bhavya"]

student_set = set(students)

for name in check_list:
    if name in student_set:
        print(name, "found")
    else:
        print(name, "not found")
# Out:
# Charan found
# Esha not found
# Bhavya found

# %% [markdown]
# **TASK 04**

# %% [markdown]
# **ORIGINAL CODE**

# %%
print("Simple Interest:", (1000 * 2 * 5) / 100)
print("Simple Interest:", (2000 * 2 * 5) / 100)
# Out:
# Simple Interest: 100.0
# Simple Interest: 200.0

# %% [markdown]
# **REFACTORED CODE**

# %%
RATE = 2
TIME = 5
PERCENT = 100
def calculate_simple_interest(principal):
    interest = (principal * RATE * TIME) / PERCENT
    print("Simple Interest:", interest)
calculate_simple_interest(1000)
calculate_simple_interest(2000)
# Out:
# Simple Interest: 100.0
# Simple Interest: 200.0

# %% [markdown]
# **TASK 05**

# %% [markdown]
# **ORIGINAL CODE**

# %%
x = 50
y = 30
z = x + y
print(z)
# Out:
# 80

# %% [markdown]
# **REFACTORED CODE**

# %%
# Define two numbers
num1 = 50
num2 = 30

# Calculate the sum of the numbers
total_sum = num1 + num2

# Display the result
print(total_sum)
# Out:
# 80
